# %% [markdown]
# # Indexing

# %%
import pandas as pd

# %%
df = pd.read_csv('K:/keypoint-moseq/videos_coordinates/buenos/721_excel.csv', sep=';')

# %%
df.head()
# Out:
#      Column1                                            Column2  \
# 0    Column1                                            Column2
# 1     scorer  DLC_resnet50_deeplabcut_singleanimal_1Sep14shu...
# 2  bodyparts                                               nose
# 3     coords                                                  x
# 4          0                                  556.8953247070312
#
#                                              Column3  \
# 0                                            Column3
# 1  DLC_resnet50_deeplabcut_singleanimal_1Sep14shu...
# 2                                               nose
# 3                                                  y
# 4                                   424.676513671875
#
#                                              Column4  \
# 0                                            Column4
# 1  DLC_resnet50_deeplabcut_singleanimal_1Sep14shu...
# 2                                               nose
# ...

# %%
df = pd.read_csv('K:/keypoint-moseq/videos_coordinates/buenos/721_excel.csv', sep=';', header=None)

# %%
df
# Out:
#               0                                                  1   \
# 0        Column1                                            Column2
# 1        Column1                                            Column2
# 2         scorer  DLC_resnet50_deeplabcut_singleanimal_1Sep14shu...
# 3      bodyparts                                               nose
# 4         coords                                                  x
# ...          ...                                                ...
# 17982      17977                                  410.3956604003906
# 17983      17978                                        409.7109375
# 17984      17979                                  408.9017333984375
# 17985      17980                                 410.14678955078125
# 17986      17981                                  410.5677490234375
#
#                                                       2   \
# 0                                                Column3
# ...

# %%
df = df.drop(df.index[:3])

# %%
df.head()
# Out:
#           0                  1                  2                   3   \
# 3  bodyparts               nose               nose                nose
# 4     coords                  x                  y          likelihood
# 5          0  556.8953247070312   424.676513671875  0.9983116388320923
# 6          1  553.3428955078125  424.0333251953125   0.998380184173584
# 7          2  550.1790771484375  422.6531677246094  0.9993870258331299
#
#                   4                  5                   6   \
# 3          right_ear          right_ear           right_ear
# 4                  x                  y          likelihood
# 5    579.27392578125  404.8413391113281  0.9993884563446045
# 6  575.7568969726562    404.90478515625  0.9992693066596985
# 7  571.6065063476562  406.8878173828125  0.9993558526039124
#
#                   7                  8                   9   ...  \
# 3           left_ear           left_ear            left_ear  ...
# ...

# %%
df.columns = pd.MultiIndex.from_tuples(
    [(df.iloc[0, col], df.iloc[1, col]) for col in range(df.shape[1])],
    names=['bodypart', 'coord']
)

# %%
df.head()
# Out:
# bodypart  bodyparts               nose                                         \
# coord        coords                  x                  y          likelihood
# 3         bodyparts               nose               nose                nose
# 4            coords                  x                  y          likelihood
# 5                 0  556.8953247070312   424.676513671875  0.9983116388320923
# 6                 1  553.3428955078125  424.0333251953125   0.998380184173584
# 7                 2  550.1790771484375  422.6531677246094  0.9993870258331299
#
# bodypart          right_ear                                         \
# coord                     x                  y          likelihood
# 3                 right_ear          right_ear           right_ear
# 4                         x                  y          likelihood
# 5           579.27392578125  404.8413391113281  0.9993884563446045
# 6         575.7568969726562    404.90478515625  0.9992693066596985
# ...

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
# bodypart  bodyparts               nose                                         \
# coord        coords                  x                  y          likelihood
# 0         bodyparts               nose               nose                nose
# 1            coords                  x                  y          likelihood
# 2                 0  556.8953247070312   424.676513671875  0.9983116388320923
# 3                 1  553.3428955078125  424.0333251953125   0.998380184173584
# 4                 2  550.1790771484375  422.6531677246094  0.9993870258331299
#
# bodypart          right_ear                                         \
# coord                     x                  y          likelihood
# 0                 right_ear          right_ear           right_ear
# 1                         x                  y          likelihood
# 2           579.27392578125  404.8413391113281  0.9993884563446045
# 3         575.7568969726562    404.90478515625  0.9992693066596985
# ...

# %%
df = df.drop(df.index[:2])

# %%
df.head()
# Out:
# bodypart bodyparts               nose                                          \
# coord       coords                  x                   y          likelihood
# 2                0  556.8953247070312    424.676513671875  0.9983116388320923
# 3                1  553.3428955078125   424.0333251953125   0.998380184173584
# 4                2  550.1790771484375   422.6531677246094  0.9993870258331299
# 5                3  547.3605346679688  421.76300048828125  0.9991506338119507
# 6                4  543.1925659179688   416.1289978027344  0.9969614148139954
#
# bodypart          right_ear                                         \
# coord                     x                  y          likelihood
# 2           579.27392578125  404.8413391113281  0.9993884563446045
# 3         575.7568969726562    404.90478515625  0.9992693066596985
# 4         571.6065063476562  406.8878173828125  0.9993558526039124
# 5         570.1121215820312  407.1229248046875  0.9994578957557678
# ...

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
# bodypart bodyparts               nose                                          \
# coord       coords                  x                   y          likelihood
# 0                0  556.8953247070312    424.676513671875  0.9983116388320923
# 1                1  553.3428955078125   424.0333251953125   0.998380184173584
# 2                2  550.1790771484375   422.6531677246094  0.9993870258331299
# 3                3  547.3605346679688  421.76300048828125  0.9991506338119507
# 4                4  543.1925659179688   416.1289978027344  0.9969614148139954
#
# bodypart          right_ear                                         \
# coord                     x                  y          likelihood
# 0           579.27392578125  404.8413391113281  0.9993884563446045
# 1         575.7568969726562    404.90478515625  0.9992693066596985
# 2         571.6065063476562  406.8878173828125  0.9993558526039124
# 3         570.1121215820312  407.1229248046875  0.9994578957557678
# ...

# %%
df = df.drop(df.columns[0], axis=1)

# %%
df.head()
# Out:
# bodypart               nose                                          \
# coord                     x                   y          likelihood
# 0         556.8953247070312    424.676513671875  0.9983116388320923
# 1         553.3428955078125   424.0333251953125   0.998380184173584
# 2         550.1790771484375   422.6531677246094  0.9993870258331299
# 3         547.3605346679688  421.76300048828125  0.9991506338119507
# 4         543.1925659179688   416.1289978027344  0.9969614148139954
#
# bodypart          right_ear                                         \
# coord                     x                  y          likelihood
# 0           579.27392578125  404.8413391113281  0.9993884563446045
# 1         575.7568969726562    404.90478515625  0.9992693066596985
# 2         571.6065063476562  406.8878173828125  0.9993558526039124
# 3         570.1121215820312  407.1229248046875  0.9994578957557678
# 4         568.0481567382812  406.6665344238281  0.9994439482688904
#
# ...

# %%
print(df.columns)

# Verifica los niveles del índice de filas
print(df.index)
# Out:
# MultiIndex([(      'nose',          'x'),
#             (      'nose',          'y'),
#             (      'nose', 'likelihood'),
#             ( 'right_ear',          'x'),
#             ( 'right_ear',          'y'),
#             ( 'right_ear', 'likelihood'),
#             (  'left_ear',          'x'),
#             (  'left_ear',          'y'),
#             (  'left_ear', 'likelihood'),
#             (    'center',          'x'),
#             (    'center',          'y'),
#             (    'center', 'likelihood'),
#             ('right_side',          'x'),
#             ('right_side',          'y'),
#             ('right_side', 'likelihood'),
#             ( 'left_side',          'x'),
#             ( 'left_side',          'y'),
#             ( 'left_side', 'likelihood'),
#             ( 'tail_base',          'x'),
#             ( 'tail_base',          'y'),
#             ( 'tail_base', 'likelihood'),
#             (  'tail_end',          'x'),
# ...

# %%
print(df.columns)
# Out:
# MultiIndex([(      'nose',          'x'),
#             (      'nose',          'y'),
#             (      'nose', 'likelihood'),
#             ( 'right_ear',          'x'),
#             ( 'right_ear',          'y'),
#             ( 'right_ear', 'likelihood'),
#             (  'left_ear',          'x'),
#             (  'left_ear',          'y'),
#             (  'left_ear', 'likelihood'),
#             (    'center',          'x'),
#             (    'center',          'y'),
#             (    'center', 'likelihood'),
#             ('right_side',          'x'),
#             ('right_side',          'y'),
#             ('right_side', 'likelihood'),
#             ( 'left_side',          'x'),
#             ( 'left_side',          'y'),
#             ( 'left_side', 'likelihood'),
#             ( 'tail_base',          'x'),
#             ( 'tail_base',          'y'),
#             ( 'tail_base', 'likelihood'),
#             (  'tail_end',          'x'),
# ...

# %%
df_stacked = df.stack(level='coord')
# Out:
# C:\Users\algarci\AppData\Local\Temp\ipykernel_21140\895829804.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stacked = df.stack(level='coord')

# %%
df_stacked.head()
# Out:
# bodypart                    nose           right_ear            left_ear  \
#   coord
# 0 likelihood  0.9983116388320923  0.9993884563446045  0.9949393272399902
#   x            556.8953247070312     579.27392578125   582.8677978515625
#   y             424.676513671875   404.8413391113281   428.3438415527344
# 1 likelihood   0.998380184173584  0.9992693066596985  0.9959938526153564
#   x            553.3428955078125   575.7568969726562   580.6383056640625
#
# bodypart                  center          right_side           left_side  \
#   coord
# 0 likelihood  0.9954078793525696  0.9514750838279724  0.9929303526878357
#   x            629.6102294921875     624.83544921875   632.9105834960938
#   y            400.8774108886719     387.70654296875   415.1402587890625
# 1 likelihood  0.9958292841911316  0.9360805153846741  0.9923366904258728
#   x            626.4947509765625    619.369384765625   630.4197998046875
#
# bodypart               tail_base            tail_end
#   coord
# ...

# %%
df_stacked.to_csv('K:/notes/Notes-tfm/721_stacked.csv', index=True)

# %%
# load data (from sleap)
keypoint_data_path = os.path.join('K:\\keypoint-moseq\\videos_coordinates\\721_excel.csv')
coordinates, confidences, bodyparts = kpms.load_keypoints(keypoint_data_path, 'deeplabcut')

# format data for modeling
data, metadata = kpms.format_data(coordinates, confidences, **config())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # load data (from sleap)
# ----> 2 keypoint_data_path = os.path.join('K:\\keypoint-moseq\\videos_coordinates\\721_excel.csv')
#       3 coordinates, confidences, bodyparts = kpms.load_keypoints(keypoint_data_path, 'deeplabcut')
#       5 # format data for modeling
#
# NameError: name 'os' is not defined
